# %% [markdown]
# <a href="https://colab.research.google.com/github/thaidaviss/us/blob/master/download.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install flickrapi
# Out:
# ...
#      |████████████████████████████████| 61kB 3.9MB/s
# ...

# %%
import flickrapi
import urllib
from PIL import Image
import urllib.request

# %%
flickr=flickrapi.FlickrAPI('c6a2c45591d4973ff525042472446ca2', '202ffe6f387ce29b', cache=True)


keyword = 'lotus'

photos = flickr.walk(text=keyword,
                     tag_mode='No known copyright restrictions',
                     tags=keyword,
                     extras='url_c',
                     per_page=500,           # may be you can try different numbers..
                     sort='relevance')

urls = []
for i, photo in enumerate(photos):
    url = photo.get('url_c')
    urls.append(url)
    
    if i > 500:
      break

# %%
for i, url in enumerate(urls):
  imagename = 'safety_vest' + str(i) + '.jpg'
  if url != None:
    urllib.request.urlretrieve(url,imagename)
    image = Image.open(imagename) 
    image.save('fire/'+imagename,'JPEG')

# %%
# !zip -r /content/fire.zip fire/
from google.colab import files
files.download("fire.zip")
# Out:
#   adding: fire/ (stored 0%)
#   adding: fire/safety_vest247.jpg (deflated 0%)
#   adding: fire/safety_vest6.jpg (deflated 0%)
#   adding: fire/safety_vest157.jpg (deflated 0%)
#   adding: fire/safety_vest208.jpg (deflated 0%)
#   adding: fire/safety_vest65.jpg (deflated 0%)
#   adding: fire/safety_vest299.jpg (deflated 0%)
#   adding: fire/safety_vest84.jpg (deflated 0%)
#   adding: fire/safety_vest490.jpg (deflated 0%)
#   adding: fire/safety_vest481.jpg (deflated 0%)
#   adding: fire/safety_vest137.jpg (deflated 0%)
#   adding: fire/safety_vest234.jpg (deflated 0%)
#   adding: fire/safety_vest72.jpg (deflated 0%)
#   adding: fire/safety_vest482.jpg (deflated 1%)
#   adding: fire/safety_vest30.jpg (deflated 0%)
#   adding: fire/safety_vest62.jpg (deflated 1%)
#   adding: fire/safety_vest59.jpg (deflated 0%)
#   adding: fire/safety_vest321.jpg (deflated 0%)
#   adding: fire/safety_vest217.jpg (deflated 0%)
#   adding: fire/safety_vest183.jpg (deflated 0%)
# ...
